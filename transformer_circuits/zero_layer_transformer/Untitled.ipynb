# %%
from datasets import load_from_disk
from tokenizers import Tokenizer
from transformers import PreTrainedTokenizerFast

# %%
data = load_from_disk('cleaned_wiki_dataset')
# tokenizer = Tokenizer.from_file('tokenizer-wiki.json')
tokenizer = PreTrainedTokenizerFast(tokenizer_file='tokenizer-wiki.json')

# %%
output
# Out:
# Encoding(num_tokens=8452, attributes=[ids, type_ids, tokens, offsets, attention_mask, special_tokens_mask, overflowing])

# %%
output['input_ids']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 output['input_ids']
#
# TypeError: 'tokenizers.Encoding' object is not subscriptable

# %%
tokenizer

# %%
outputs = tokenizer(
    data[0]['text'],
    truncation=True,
    max_length=16,
    return_overflowing_tokens=True,
    return_length=True,
)

# %%
outputs
# Out:
# {'input_ids': [[11697, 1211, 507, 438, 2010, 5383, 470, 2799, 561, 507, 442, 1424, 655, 465, 4059, 470], [5544, 283, 713, 2025, 5384, 619, 445, 733, 443, 304, 620, 3867, 465, 16939, 447, 11697], [1211, 5968, 502, 441, 13317, 465, 441, 992, 445, 636, 544, 5399, 476, 522, 19074, 619], [445, 3154, 467, 17578, 445, 470, 7193, 1354, 447, 509, 438, 8146, 1500, 496, 3287, 2799], [445, 2967, 497, 441, 17351, 3023, 1500, 465, 441, 2010, 10693, 445, 544, 507, 2797, 2123], [4108, 1183, 16685, 470, 10380, 3166, 9778, 1211, 509, 441, 10380, 3166, 3287, 515, 10380, 3166], [16227, 514, 465, 441, 6720, 2799, 445, 470, 685, 438, 2428, 3255, 2012, 533, 2968, 496], [18582, 470, 16227, 447, 6433, 3169, 456, 10047, 2138, 5934, 12633, 588, 1197, 1123, 441, 5673], [465, 5934, 1089, 445, 2017, 1537, 445, 577, 1654, 3245, 447, 533, 441, 5222, 465, 8448], [12633, 655, 6268, 445, 442, 1424, 472, 1211, 6043, 4059, 672, 4171, 447, 1729, 13779, 465], [11697, 546, 3488, 612, 929, 2547, 1570, 445, 2149, 11697, 1211
# ...

# %%
output = tokenizer.encode(data[0]['text'])
output.tokens
# Out:
# ['Ġanarch',
#  '##ism',
#  'Ġis',
#  'Ġa',
#  'Ġpolitical',
#  'Ġphilosophy',
#  'Ġand',
#  'Ġmovement',
#  'Ġthat',
#  'Ġis',
#  'Ġs',
#  '##cept',
#  '##ical',
#  'Ġof',
#  'Ġauthority',
#  'Ġand',
#  'Ġreject',
#  '##s',
#  'Ġall',
#  'Ġinvol',
#  '##unt',
#  '##ary',
#  'Ġ,',
#  'Ġco',
#  '##er',
#  '##c',
#  '##ive',
#  'Ġforms',
#  'Ġof',
#  'Ġhierarchy',
#  'Ġ.',
#  'Ġanarch',
#  '##ism',
#  'Ġcalls',
#  'Ġfor',
#  'Ġthe',
#  'Ġabolition',
#  'Ġof',
#  'Ġthe',
#  'Ġstate',
#  'Ġ,',
#  'Ġwhich',
#  'Ġit',
#  'Ġholds',
#  'Ġto',
#  'Ġbe',
#  'Ġunnecess',
#  '##ary',
#  'Ġ,',
#  'Ġund',
#  '##es',
#  '##irable',
#  'Ġ,',
#  'Ġand',
#  'Ġharm',
#  '##ful',
#  'Ġ.',
#  'Ġas',
#  'Ġa',
#  'Ġhistorically',
#  'Ġleft',
#  'Ġ-',
#  'Ġwing',
#  'Ġmovement',
#  'Ġ,',
#  'Ġplaced',
#  'Ġon',
#  'Ġthe',
#  'Ġfart',
#  '##hest',
#  'Ġleft',
#  'Ġof',
#  'Ġthe',
#  'Ġpolitical',
#  'Ġspectrum',
#  'Ġ,',
#  'Ġit',
#  'Ġis',
#  'Ġusually',
#  'Ġdescribed',
#  'Ġalongside',
#  'Ġcommun',
# ...

# %%
normalized = tokenizer.normalizer.normalize_str(data[0]['text'])
normalized
# Out:
# 'anarchism is a political philosophy and movement that is sceptical of authority and rejects all involuntary, coercive forms of hierarchy. anarchism calls for the abolition of the state, which it holds to be unnecessary, undesirable, and harmful. as a historically left-wing movement, placed on the farthest left of the political spectrum, it is usually described alongside communalism and libertarian marxism as the libertarian wing (libertarian socialism) of the socialist movement, and has a strong historical association with anti-capitalism and socialism. humans lived in societies without formal hierarchies long before the establishment of formal states, realms, or empires. with the rise of organised hierarchical bodies, scepticism toward authority also rose. although traces of anarchist thought are found throughout history, modern anarchism emerged from the enlightenment. during the latter half of the 19th and the first decades of the 20th century, the anarchist movement flourished i
# ...

# %%
pre_tokenized = tokenizer.pre_tokenizer.pre_tokenize_str(normalized)
pre_tokenized
# Out:
# [('Ġanarchism', (0, 9)),
#  ('Ġis', (10, 12)),
#  ('Ġa', (13, 14)),
#  ('Ġpolitical', (15, 24)),
#  ('Ġphilosophy', (25, 35)),
#  ('Ġand', (36, 39)),
#  ('Ġmovement', (40, 48)),
#  ('Ġthat', (49, 53)),
#  ('Ġis', (54, 56)),
#  ('Ġsceptical', (57, 66)),
#  ('Ġof', (67, 69)),
#  ('Ġauthority', (70, 79)),
#  ('Ġand', (80, 83)),
#  ('Ġrejects', (84, 91)),
#  ('Ġall', (92, 95)),
#  ('Ġinvoluntary,', (96, 108)),
#  ('Ġcoercive', (109, 117)),
#  ('Ġforms', (118, 123)),
#  ('Ġof', (124, 126)),
#  ('Ġhierarchy.', (127, 137)),
#  ('Ġanarchism', (138, 147)),
#  ('Ġcalls', (148, 153)),
#  ('Ġfor', (154, 157)),
#  ('Ġthe', (158, 161)),
#  ('Ġabolition', (162, 171)),
#  ('Ġof', (172, 174)),
#  ('Ġthe', (175, 178)),
#  ('Ġstate,', (179, 185)),
#  ('Ġwhich', (186, 191)),
#  ('Ġit', (192, 194)),
#  ('Ġholds', (195, 200)),
#  ('Ġto', (201, 203)),
#  ('Ġbe', (204, 206)),
#  ('Ġunnecessary,', (207, 219)),
#  ('Ġundesirable,', (220, 232)),
#  ('Ġand', (233, 236)),
#  ('Ġharmful.', (237, 245)),
# ...

# %%
dir(tokenizer.model)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'continuing_subword_prefix',
#  'dropout',
#  'end_of_word_suffix',
#  'from_file',
#  'fuse_unk',
#  'get_trainer',
#  'id_to_token',
#  'read_file',
#  'save',
#  'token_to_id',
#  'tokenize',
#  'unk_token']

# %%
tokenized = tokenizer.model.tokenize(pre_tokenized)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 tokenized = tokenizer.model.tokenize(pre_tokenized)
#
# ...

# %%
tokenizer.get_vocab()
# Out:
# {'Ġjournalists##': 13485,
#  '##aâĢĶ': 21283,
#  'Ġdistortion##': 43452,
#  'Ġhenning##': 38682,
#  'Ġextensive##': 6395,
#  'Ġalgiers,##': 12732,
#  'Ġhake##': 26338,
#  '##tsch': 39886,
#  '##erhol': 48386,
#  'Ġthoughts##': 16126,
#  '##ulture,##': 34992,
#  '##¢': 325,
#  'Ġdissolved##': 13668,
#  'Ġdefinitely##': 38484,
#  'Ġupgrading##': 41367,
#  '##hed##': 46279,
#  '##Ã¦': 21484,
#  '##+fr': 47842,
#  'Ġtav': 47952,
#  '##ha##': 6681,
#  'Ġ"c"##': 38120,
#  '##nÃ©,##': 32033,
#  'Ġmatri': 10966,
#  'Ġoverall,##': 22930,
#  'Ġi)##': 32540,
#  'Ġdeep-water##': 20279,
#  'Ġdisappears##': 40287,
#  '##on-shaped##': 48815,
#  '##usin': 26279,
#  'Ġbusy##': 28541,
#  'Ġinaccessible##': 21023,
#  'Ġdecreasing##': 8478,
#  '##urface##': 33413,
#  '##o-sat': 39924,
#  'Ġnumerically##': 35199,
#  '##kie##': 46672,
#  '##rness': 45523,
#  '##eenth##': 15039,
#  '##auti': 5347,
#  'Ġknox##': 27115,
#  'Ġdeveloped##': 1822,
#  'Ġphilhar': 22544,
#  'Ġbeekeepers##': 31282,
# ...
